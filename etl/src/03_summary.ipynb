# %%
import pandas as pd

# %%
df = pd.read_csv("/workspaces/demo-devcontainer/src/holding.csv", nrows=100000)

# %%
df
# Out:
#         portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0      2998623  2020/11/30              1  2021/01/08         2.55
# 1      2998623  2020/11/30              2  2021/01/08         1.98
# 2      2998623  2020/11/30              3  2021/01/08         1.89
# 3      2998623  2020/11/30              4  2021/01/08         1.75
# 4      2998623  2020/11/30              5  2021/01/08         1.65
# ...        ...         ...            ...         ...          ...
# 99995  306412e  2020/12/31            170  2021/01/08         0.07
# 99996  306412e  2020/12/31            171  2021/01/08         0.07
# 99997  306412e  2020/12/31            171  2021/01/08         0.07
# 99998  306412e  2020/12/31            173  2021/01/08         0.07
# 99999  306412e  2020/12/31            174  2021/01/08         0.07
#
#        nbr_shares    market_val  \
# 0       7078982.0  3.103426e+08
# 1       3087680.0  2.412404e+08
# 2       3714760.0  2.296836e+08
# ...

# %%
df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
df.head(20)
# Out:
#      portno   report_dt  security_rank      eff_dt  percent_tna   nbr_shares  \
# 0   2998623  2020/11/30              1  2021/01/08         2.55    7078982.0
# 1   2998623  2020/11/30              2  2021/01/08         1.98    3087680.0
# 2   2998623  2020/11/30              3  2021/01/08         1.89    3714760.0
# 3   2998623  2020/11/30              4  2021/01/08         1.75    2815186.0
# 4   2998623  2020/11/30              5  2021/01/08         1.65    5248941.0
# 5   2998623  2020/11/30              6  2021/01/08         1.64     866386.0
# 6   2998623  2020/11/30              7  2021/01/08         1.63    2194727.0
# 7   2998623  2020/11/30              8  2021/01/08         1.60    5045923.0
# 8   2998623  2020/11/30              9  2021/01/08         1.59    1403360.0
# 9   2998623  2020/11/30             10  2021/01/08         1.54    3065766.0
# 10  2998623  2020/11/30             11  2021/01/08         1.54  186854700.0
# ...

# %%
df.tail(20)
# Out:
#         portno   report_dt  security_rank      eff_dt  percent_tna  \
# 99980  306412e  2020/12/31            152  2021/01/08         0.07
# 99981  306412e  2020/12/31            152  2021/01/08         0.07
# 99982  306412e  2020/12/31            152  2021/01/08         0.07
# 99983  306412e  2020/12/31            152  2021/01/08         0.07
# 99984  306412e  2020/12/31            159  2021/01/08         0.07
# 99985  306412e  2020/12/31            159  2021/01/08         0.07
# 99986  306412e  2020/12/31            161  2021/01/08         0.07
# 99987  306412e  2020/12/31            162  2021/01/08         0.07
# 99988  306412e  2020/12/31            162  2021/01/08         0.07
# 99989  306412e  2020/12/31            164  2021/01/08         0.07
# 99990  306412e  2020/12/31            164  2021/01/08         0.07
# 99991  306412e  2020/12/31            164  2021/01/08         0.07
# 99992  306412e  2020/12/31            167  2021/01/08         0.07
# ...

# %%
df[100:105]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 100  2998623  2020/11/30            101  2021/01/08         0.21  17148000.0
# 101  2998623  2020/11/30            102  2021/01/08         0.21  14118000.0
# 102  2998623  2020/11/30            103  2021/01/08         0.20  20716000.0
# 103  2998623  2020/11/30            104  2021/01/08         0.20  17930000.0
# 104  2998623  2020/11/30            105  2021/01/08         0.20  24298000.0
#
#       market_val                                   security_name     cusip
# 100  25722000.00        ON Semiconductor Corp 1.000% 01-Dec-2020  682189AK
# 101  25519881.75              Zillow Group Inc 2.75% 15-MAY-2025  98954MAH
# 102  24879675.69  Live Nation Entertainment Inc 2.5% 15-MAR-2023  538034AQ
# 103  24866668.75    Neurocrine Biosciences Inc 2.25% 15-MAY-2024  64125CAD
# 104  24546760.01                   Southern Co 2.35% 01-JUL-2021  842587CS

# %%
df.loc[[1, 3, 5], :]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
#
#      market_val                    security_name     cusip
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 5  1.997713e+08          GOLDMAN SACHS GROUP INC  38141G10

# %%
df.loc[1:5, :]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
#
#      market_val                    security_name     cusip
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10
# 5  1.997713e+08          GOLDMAN SACHS GROUP INC  38141G10

# %%
df.loc[1:5, ["portno", "report_dt"]]
# Out:
#     portno   report_dt
# 1  2998623  2020/11/30
# 2  2998623  2020/11/30
# 3  2998623  2020/11/30
# 4  2998623  2020/11/30
# 5  2998623  2020/11/30

# %%
df.iloc[1:5, [0, 1]]
# Out:
#     portno   report_dt
# 1  2998623  2020/11/30
# 2  2998623  2020/11/30
# 3  2998623  2020/11/30
# 4  2998623  2020/11/30

# %%
df.columns
# Out:
# Index(['portno', 'report_dt', 'security_rank', 'eff_dt', 'percent_tna',
#        'nbr_shares', 'market_val', 'security_name', 'cusip'],
#       dtype='object')

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.dtypes
# Out:
# portno            object
# report_dt         object
# security_rank      int64
# eff_dt            object
# percent_tna      float64
# nbr_shares       float64
# market_val       float64
# security_name     object
# cusip             object
# dtype: object

# %%
df["portno"].dtype
# Out:
# dtype('O')

# %%
df["portno"]
# Out:
# 0        2998623
# 1        2998623
# 2        2998623
# 3        2998623
# 4        2998623
#           ...
# 99995    306412e
# 99996    306412e
# 99997    306412e
# 99998    306412e
# 99999    306412e
# Name: portno, Length: 100000, dtype: object

# %%
df["portno"].unique()
# Out:
# array(['2998623', '2998638', '2998809', '2998821', '2999052', '2999757',
#        '3000255', '300035d', '3001404', '3002313', '3002316', '300251d',
#        '300283b', '3003702', '300383a', '3003846', '3004239', '300474c',
#        '3005232', '3007017', '300783f', '3008148', '300814e', '3008151',
#        '3008154', '3008157', '301242f', '3013614', '301370d', '301380c',
#        '301421a', '3014637', '3014706', '301484a', '3015021', '3015330',
#        '3026844', '302704b', '302740b', '302740e', '3029028', '302974e',
#        '3029832', '3030108', '303010b', '3030138', '3030444', '3030510',
#        '303054c', '3030828', '305112c', '3055317', '305531a', '305531d',
#        '3055617', '3055905', '305623b', '305630d', '3056463', '305702a',
#        '3058311', '3060003', '3060411', '3060414', '3060528', '3060531',
#        '3060537', '3060540', '3060555', '306055e', '3060618', '306061b',
#        '306061e', '3060630', '3060642', '3060645', '3060648', '3060654',
# ...

# %%
df["portno"].unique().__len__()
# Out:
# 366

# %%
df["portno"].nunique()
# Out:
# 366

# %%
len(df["portno"].unique())
# Out:
# 366

# %%
df["nbr_shares"].mean()
# Out:
# 66273097.77758

# %%
df[["nbr_shares", "security_rank"]].mean()
# Out:
# nbr_shares       6.627310e+07
# security_rank    1.370033e+03
# dtype: float64

# %%
df["portno"].value_counts()
# Out:
# portno
# 3062442    9285
# 3062436    7676
# 3062403    3917
# 3062439    3311
# 3062352    3279
#            ...
# 3063750       1
# 306201c       1
# 306070b       1
# 2999757       1
# 3061614       1
# Name: count, Length: 366, dtype: int64

# %%
df.describe()
# Out:
#        security_rank    percent_tna    nbr_shares    market_val
# count  100000.000000  100000.000000  1.000000e+05  1.000000e+05
# mean     1370.033410       0.278084  6.627310e+07  6.621190e+06
# std      2006.655863       1.864025  3.099766e+09  4.122161e+07
# min         1.000000    -101.000000 -8.451950e+10 -4.798583e+09
# 25%       165.000000       0.010000  3.517325e+04  1.515223e+05
# 50%       565.000000       0.030000  2.763050e+05  6.662634e+05
# 75%      1657.000000       0.140000  1.360000e+06  3.256665e+06
# max      9290.000000     100.290000  2.950900e+11  4.901722e+09

# %%
df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
df.tail(3)
# Out:
#         portno   report_dt  security_rank      eff_dt  percent_tna  \
# 99997  306412e  2020/12/31            171  2021/01/08         0.07
# 99998  306412e  2020/12/31            173  2021/01/08         0.07
# 99999  306412e  2020/12/31            174  2021/01/08         0.07
#
#        nbr_shares  market_val  \
# 99997  12000000.0  14594147.0
# 99998  11485000.0  14497554.0
# 99999  12655000.0  14493687.0
#
#                                            security_name     cusip
# 99997  Massachusetts School Building Authority 5% 15-...  576000YJ
# 99998  Massachusetts Water Resources Authority 5% 01-...  576051PH
# 99999  Contra Costa Community College District 5% 01-...  212204HD

# %%
df["portno"] == "2998623"
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Name: portno, Length: 100000, dtype: bool

# %%
portno_filter = df["portno"] == "2998623"
df[portno_filter]
df[df["portno"] == "2998623"]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0    2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1    2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2    2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3    2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4    2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
# ..       ...         ...            ...         ...          ...         ...
# 346  2998623  2020/11/30            352  2021/01/08         0.00      1303.0
# 347  2998623  2020/11/30            352  2021/01/08         0.00      3702.0
# 348  2998623  2020/11/30            352  2021/01/08         0.00      5645.0
# 349  2998623  2020/11/30            352  2021/01/08         0.00         1.0
# 350  2998623  2020/11/30            352  2021/01/08         0.00         0.0
#
# ...

# %%
columns = ["Name", "Age", "Height"]
data = [
		["Ted", 24, 177],
		["Judy", 27, 183],
]
df2 = pd.DataFrame(data=data, columns=columns)
df2
# Out:
#    Name  Age  Height
# 0   Ted   24     177
# 1  Judy   27     183

# %%
df2["Name"] == "Ted"
# Out:
# 0     True
# 1    False
# Name: Name, dtype: bool

# %%
"""
select name, age, hight from df2 where name = 'Ted';
"""

df2[df2["Name"] == "Ted"]
# Out:
#   Name  Age  Height
# 0  Ted   24     177

# %%
portno_filter = df["portno"] == "2998623"
share_percentage_filter = df["percent_tna"] < 1

# %%
df[portno_filter & share_percentage_filter]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 32   2998623  2020/11/30             33  2021/01/08         0.97   2350480.0
# 33   2998623  2020/11/30             34  2021/01/08         0.94    724928.0
# 34   2998623  2020/11/30             35  2021/01/08         0.94   3616628.0
# 35   2998623  2020/11/30             36  2021/01/08         0.91   2015089.0
# 36   2998623  2020/11/30             37  2021/01/08         0.88    596059.0
# ..       ...         ...            ...         ...          ...         ...
# 346  2998623  2020/11/30            352  2021/01/08         0.00      1303.0
# 347  2998623  2020/11/30            352  2021/01/08         0.00      3702.0
# 348  2998623  2020/11/30            352  2021/01/08         0.00      5645.0
# 349  2998623  2020/11/30            352  2021/01/08         0.00         1.0
# 350  2998623  2020/11/30            352  2021/01/08         0.00         0.0
#
# ...

# %%
"""
select *
from df
where portno = '2998623'
    and (
        percent_tna > 2 or percent_tna < 0.3
    )
"""

portno_filter = df["portno"] == "2998623"
share_percentage_filter_1 = df["percent_tna"] > 2
share_percentage_filter_2 = df["percent_tna"] < 0.3

df[portno_filter & (share_percentage_filter_1 | share_percentage_filter_2)]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0    2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 93   2998623  2020/11/30             94  2021/01/08         0.29  34380000.0
# 94   2998623  2020/11/30             95  2021/01/08         0.27  20265000.0
# 95   2998623  2020/11/30             96  2021/01/08         0.27    505265.0
# 96   2998623  2020/11/30             97  2021/01/08         0.26  31406000.0
# ..       ...         ...            ...         ...          ...         ...
# 346  2998623  2020/11/30            352  2021/01/08         0.00      1303.0
# 347  2998623  2020/11/30            352  2021/01/08         0.00      3702.0
# 348  2998623  2020/11/30            352  2021/01/08         0.00      5645.0
# 349  2998623  2020/11/30            352  2021/01/08         0.00         1.0
# 350  2998623  2020/11/30            352  2021/01/08         0.00         0.0
#
# ...

# %%
df.groupby("portno").size()
# Out:
# portno
# 2998623    351
# 2998638     77
# 2998809     70
# 2998821     54
# 2999052      2
#           ...
# 3064122     28
# 3064125     27
# 3064128     27
# 306412b     28
# 306412e    174
# Length: 366, dtype: int64

# %%
df.groupby("portno").sum()
# Out:
#                                                  report_dt  security_rank  \
# portno
# 2998623  2020/11/302020/11/302020/11/302020/11/302020/1...          61888
# 2998638  2020/11/302020/11/302020/11/302020/11/302020/1...           3021
# 2998809  2020/11/302020/11/302020/11/302020/11/302020/1...           2485
# 2998821  2020/11/302020/11/302020/11/302020/11/302020/1...           1485
# 2999052                               2020/10/312020/10/31            634
# ...                                                    ...            ...
# 3064122  2020/11/302020/11/302020/11/302020/11/302020/1...            406
# 3064125  2020/11/302020/11/302020/11/302020/11/302020/1...            378
# 3064128  2020/11/302020/11/302020/11/302020/11/302020/1...            378
# 306412b  2020/11/302020/11/302020/11/302020/11/302020/1...            406
# 306412e  2020/12/312020/12/312020/12/312020/12/312020/1...          15180
#
# ...

# %%
df.groupby("portno")["security_rank"].sum()
# Out:
# portno
# 2998623    61888
# 2998638     3021
# 2998809     2485
# 2998821     1485
# 2999052      634
#            ...
# 3064122      406
# 3064125      378
# 3064128      378
# 306412b      406
# 306412e    15180
# Name: security_rank, Length: 366, dtype: int64

# %%
df.groupby("portno").get_group("3064128")
# Out:
#         portno   report_dt  security_rank      eff_dt  percent_tna  \
# 99771  3064128  2020/11/30              1  2021/01/08         9.94
# 99772  3064128  2020/11/30              2  2021/01/08         8.01
# 99773  3064128  2020/11/30              3  2021/01/08         7.12
# 99774  3064128  2020/11/30              4  2021/01/08         6.31
# 99775  3064128  2020/11/30              5  2021/01/08         6.21
# 99776  3064128  2020/11/30              6  2021/01/08         5.23
# 99777  3064128  2020/11/30              7  2021/01/08         5.06
# 99778  3064128  2020/11/30              8  2021/01/08         4.87
# 99779  3064128  2020/11/30              9  2021/01/08         4.80
# 99780  3064128  2020/11/30             10  2021/01/08         4.42
# 99781  3064128  2020/11/30             11  2021/01/08         4.24
# 99782  3064128  2020/11/30             12  2021/01/08         4.22
# 99783  3064128  2020/11/30             13  2021/01/08         3.97
# ...
